# %% [markdown]
# <a href="https://colab.research.google.com/github/afrah1999/Flutter-IBM-Watson-Assistant-/blob/main/Sentiment_Analysis_for_Arabic_Tweets_Related_to_Riyadh_Season_using_LSTM_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tweepy as tw
import pandas as pd
import csv
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, SimpleRNN, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re

# %%
csvFile = open('Tweets.csv', 'a')
csvWriter = csv.writer(csvFile)

# %%
for tweet in tw.Cursor(api.search,
                           q=HashValue,
                           count=20,
                           lang="ar",
                           since=date_since,
                           tweet_mode='extended').items(300):
    
    print (tweet.created_at, tweet.full_text)
    csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf-8-sig')])

print ("Scraping finished and saved to "+HashValue+".csv")
# Out:
# 2022-07-12 06:38:32 @HussHus60722845 @NFCST @FAZI838 والله المصخره ناديك اللي ريحته طلعت على مستوى اسيا وصار الكل يعرف ان بطولاته نتيجة فساد حتى بطولة موسم الرياض جابوها لكم اشتهرتو بنادي الفار واللجان 🤣🤣🤣
# 2022-07-12 03:31:34 @vip__naser مسخره وعدم  خوف  من  الله رجعنا  الى  الجاهليه والجواري  ترقص  امام  الرجال  شي  مخزي   في  حفل  كان  لا  اي  مطرب  مطربه  في  موسم  الرياض  او  الكويت  او  غيره  من  متى ياحفيدات  الصحابيات  ترقصن  مثل الجوارى  امام الرجال بلا  خوف  من الله  ومن  متى  يا  احفاد عمر  وخالد هالرقص
# 2022-07-12 03:03:01 @Turkiii1420 @MmMody1 @uiiqlc @Yalrashid موسم الرياض فرصة تعرفنا على بنات السعودية ، يا زين بناتكم يا أخي ! حلو انكم انفتحتم على العالم ! على الاقل نشوف بناتكم 😌✌️
# 2022-07-12 00:26:59 شوف المشاريع الترفيهية ياعمي لاتقلي موسم #الرياض والدخول ب 1000ولا موسم #جدة والدخول ب 700 ولا تشوف شيء من هذا الروعه تعال هذا المقهى وانبسط تغدا او تعشي وقهوة والشاهي ب250 ريال فقط لكل وكل العائلة مو بس بشخص مثل موسم جدة والرياض😂🇹🇷🇹🇷✌️ https://t.co/yp7tvOeJMH
# 2022-07-11 19:03:51 دقيقة مو قالت في موسم الرياض ان هذي اول مره واخر مره تشيل الحجاب؟  #موضي_الشمراني https://t.co/JLfbS72LTq
# 2022-07-11 18:29:59 @banwan16 نريد الحريات الموجوده في المملكة وسوف نأخذها
# واريد جواب صريح بما انك اسلامي
#
# هل تعتبر ما يحصل في موسم الرياض والحفلات الغنائية والمهرجانات وكل ما هو جميل في الشقيقة الكبرى  "فساد ومجون" منتظر الاجابه، واتمنى انك تجاوب عليه بدون اي محاوله انك تخرج عن فحوى السؤال استاذ محمد. https://t.co/aInLRBXvrg
# 2022-07-11 14:32:31 خذها وانت ماشي تخلي يومك مو عادي 😋🫰
#
# .
# .
# .
#
#  #كيمس #kims #قهوة_المساء #موهيتو #عيد_الأضحى_المبارك #موسم_جدة #قهوة #الرياض #ايروبيس #موسم_الرياض #رساله_lليوم #موسم_جدة #جدة #القهوة_السعودية #ايسكريم  #coffe #عشاق_القهوة #الطايف #المدينة #مكة #القنفذة #عام_القهوة_السعودية_2022 https://t.co/5hYHH8lLid
�😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂 #الاربعه_الكبار https://t.co/I7O6YQBK6c
# 2022-07-02 11:49:20 بالله عليكم تقارنون الصغار بكبير الرياض بطل آسيا الزعيم الملكي العالمي الاستثنائي؟!
# وبالأخص الفقر الترشيحي الحالمي إللي طرده جلاده من ثلاث بطولات في موسم واحد بين القطيع الأحمق جمهوره الحالم في ملعبنا المسروق !!🤣🤣🤣  #الاربعه_الكبار https://t.co/LK20CU1kE5
# 2022-07-02 11:48:39 بالله عليكم تقارنون الصغار بكبير الرياض بطل آسيا الزعيم الملكي العالمي الاستثنائي؟!
# وبالأخص الفقر الترشيحي الحالمي إللي طرده جلاده من ثلاث بطولات في موسم واحد بين القطيع الأحمق جمهوره الحالم في ملعبنا المسروق !!🤣🤣🤣  #الاربعه_الكبار https://t.co/RtnFRQDo4M
# 2022-07-02 10:30:27 يعني حطوا ثلاث أترام دراسة قللوا الإجازة الصيفية من اربع شهور لشهر ونص محاولة منهم يحدون من عدد السيّاح في الخارج بس مافي أمل ، ترا مو كل الشعب يعجبهم خياس موسم الرياض وموسم جدة الحفلات والرقص والفعاليات النايمة لأصحاب الـ iQ المنخفض امثال سمول كابتشينو فقط https://t.co/uKNiLLXjNu
# Scraping finished and saved to [#موسم_الرياض OR #موسم_الرياض2021 OR موسم الرياض]* AND ( استهتار OR حلو OR مبهر OR مو OR رائع OR جميل OR عدا OR فساد OR بطل OR الرذيلة OR مخزي OR اوقفوا OR شكر OR الجاهلية OR تحرش OR انجاز OR عدا)  -(filter:retweets OR فحـص OR احجز  OR بطاقه OR لقاح OR  سجلي OR فنانة OR فنان OR اطلب OR بطاقتك OR  متجر OR  نساعدك  OR  واتساب OR للتواصل OR التواصل OR قرض OR موظف OR حفلة OR سائق OR عندي OR سنابي OR تذاكر OR ادعموني OR تأشيرات) .csv

# %%
#Collecting data

tweets = tw.Cursor(api.search,q=HashValue,lang="ar", since=date_since).items(300)

users_locs = [[tweet.text,tweet.user.screen_name, tweet.user.location] for tweet in tweets]

tweet_text = pd.DataFrame(data=users_locs,  columns=['tweet','user', "location"])

pd.set_option("display.max_rows", None, "display.max_columns", None)

tweet_text.to_csv('1.csv')

tweet_text #unlabeld dataset
# Out:
#                                                 tweet             user  \
# 0   @HussHus60722845 @NFCST @FAZI838 والله المصخره...        n00039251
# 1   @vip__naser مسخره وعدم  خوف  من  الله رجعنا  ا...  ab1238aa87b9476
# 2   @Turkiii1420 @MmMody1 @uiiqlc @Yalrashid موسم ...      DRISSELKAKE
# 3   شوف المشاريع الترفيهية ياعمي لاتقلي موسم #الري...      alamnalwqai
# 4   دقيقة مو قالت في موسم الرياض ان هذي اول مره وا...           MRNX70
# 5   @banwan16 نريد الحريات الموجوده في المملكة وسو...     saeedalomani
# 6   خذها وانت ماشي تخلي يومك مو عادي 😋🫰\n\n.\n.\n....     kimscoffeesa
# 7   @xquxx @looolooo2007 @Mohammed11saudi @alk3aam...     loveksa20221
# 8   @AlhdhyfyRdad @Uy6PLlUJILNoFsH ياريت سياسه يا ...            Ro7zo
# 9   @ZZZZOO21 مافيه فريق في السعودية هبط وبعد الهب...     abufaisl1388
# 10  @jalz1212 @Ask_Alriyadh1 فاتك موسم الرياض فيها...     reemumfaisal
# 11  @VIP_a57 @Abu_Turab02 @mkhfnaakaw @JokerNaar @...  AboAbba82583757
# 12  @Gamers8_AR موسم الرياض اطلق من موسم جدة الخاا...           IJsinx
# 13  @BAlmqwshy @forever_navruz @saraadelmo @pKZrnK...         zeboly34
# 14  @Ibn_Said1 @Mesh37411446 @uiBouncy @ScreenMix ...            ci408
# 15  @Jeddahseasonsa ماعندكم سالفة قافلين السيتي وو...     ahmedzone010
# 16  @Salmabll1 انتي ما شفتي وش صار لما موسم الرياض...          jk7amal
# 17  @ketab_a #حافي_في_شوارع_الثمانينات \n \nممتع ب...     magd_alarobh
# 18  @Etidal جميل هذا الطرح يا اعتدال 🤙🏻\nواكبر دلي...       folkprince
# 19  @omarmsod هذي الاشياء اللي نرفع بها روسنا مو م...          ivr1418
# 20            @gorgeous4ew خالي هذا حج مو موسم الرياض         Na_ku_ku
# 21  حجي ترا حج مو موسم الرياض https://t.co/BfELiFe5Jr            7_4_1
# 22  @ABDEL_cv5 هيه بذي الكشخه تروح موسم الرياض مو ...        i_moha_77
# 23  @hsn1nsh @darrk_99 @Omar71446537 @chaaban_ebra...            i_0og
# 24  @hsn1nsh @darrk_99 @Omar71446537 @chaaban_ebra...            i_0og
# 25    ترى حج مو موسم الرياض 😂 https://t.co/W8Lp4nbQe7          BnSayer
# 26  @Celebrty_0 ههههههههههه ياباشا هذا حج مو موسم ...       3BOODY2003
# 27  @mwtn7rr @c2txiKLBOwLCp7A @Matloob76583135 @s_...         Veritol9
# 28                        @bixwd مو موسم الرياض هو!!!     Az61199242Az
# 29  @whrumor الله يتقبل حجكم بس ترا مو موسم الرياض...         rooh_500
# 30  مو موسم الرياض يمددون لك 😂 https://t.co/Sc0C6w...           kjm199
# 31  @model_ot موسم الرياض ومكة ومزرعة جدي ومحطة ال...          Gate_66
# 32  كيف نقنعه انه حج مو موسم الرياض نمدده له https...         rraghd10
# 33  حج يا حبيبي مو موسم الرياض https://t.co/0TOCur...          qiiii42
# 34  احد يقول لعبدو حج مو موسم الرياض\n https://t.c...            N0iff
# 35  الوطنجيين ما افهمهم يعني اكيد اي مسلم بيحج بمك...         yas10___
# 36  @velvet7_ @DrAbdullahsulmi لاحول ولا قوة إلا ب...        Musadad37
# 37  @Queen_9k ايه ترا نحسدكم ، في الرياض عندكم كل ...      batman_9911
# 38  @KSaudi1923 @haifaotaa طيب قرر الي تبيه بس لا ...            kw834
# 39  مساء الخير، قرب العيد وكثير منكم محتاج يعرض اع...   Graphic_desiin
# 40  @esha16b والله اذا كذا انا كان ودي انه موسم ال...      guardiiola_
# 41  @FahadIcon @iLayla97 @YG_iKONIC مو سالفة مو مق...          pui__34
# 42  @JAHMED313 @xYz0a9 @xmorr_ @FE7Z_ @tayloorv @S...            5Ljct
# 43  #موسم_الجيمرز إنجاز أعمال المشبات والقرميد  وم...     aboraed59021
# 44  عيب الهوالات.. إن كنت كاره فلا تكن مدلس وكاذب....      al_zhra0001
# 45  عنجد غريب انه السعوديين بيروحو إلى موسم الرياض...       GND_arabic
# 46  @bdallh294641661 اي صح عليك \nبس حلوه جيتها اي...      mohmad_F_20
# 47  @ail2233445 دخلت حسابك الصهيوني واكتشفت انك أص...           Rmviol
# 48  @almatarapp حلو مشكلة الحرمه اللي مرسله بالتغر...       geen__2000
# 49  هسه لو تصير عدنا اشياء مثل موسم الرياض او فبرا...   nooneloveyouu1
# 50  @notayll @NovaSilan يابويا الرياض كبيره مره في...        CaryDay66
# 51  قاعده احلم ان ذا بويز يجو موسم الرياض ويكون اي...     lomlxiaoting
# 52  @saudiah077 @Me4008000 حلو المهم الكذاب بيخش ا...        IntelgntM
# 53   @ziiziisnowi مو بكيفك موسم الرياض بيجي وهم بيجون          luvrnjm
# 54  @Turki_alalshikh معالي المستشار انا عازف عود و...       NK11320123
# 55  @angelillv موسم الرياض كنتو تروحو له لان ماعند...         sltn_550
# 56  قلتها زمان بس يفتح الحجر تشوفو السعوديين في ال...        Leila_la7
# 57  @basssl2019 @SaudiNews50 ايش دخل الان !! موسم ...     ahmedzone010
# 58  وانا على الله أصلاً عاوزة احضر موسم الرياض ولا...           Ghgor2
# 59  ٣٦ ؟ و زعلان ؟ زين موسم جده مو الرياض يمكن يكن...          VIIEIII
# 60  @dy57_ 10/6 والله يا انكم سلكتو لنا تسليك مانق...           _SA50_
# 61  @dy57_ مو حلى هي ترى لازم كل مدينه نحط موسم ال...         eyad_hhh
# 62  @alekhbariyatv السبب الذي اوضحته جزء بسيط من ا...    the_Silence84
# 63  @dy57_ مااش مو زي موسم الرياض اخذ ضجه كبيرررره...            732Rn
# 64  @SaudiSports1 @nzihhh بطولة كأس الكؤوس الاسيوي...            9RHFC
# 65  @BetterCallMy @FFearFFul @AdeleAccess ياخي شفي...        zuhair_80
# 66  مخطط أزور الستي ووك والحمدلله جيته غيرت جو حجز...           9vxxvv
# 67  أكره الناس اللي دايم تنتقد، مو عاجبها شيء\nالم...           imj__1
# 68  @abu_sbaa1 @SMGBSH طيب انا اعرف سعودي قبيلي وي...          iailla_
# 69  @20cov @2MIRIAM_2 @dy57_ رايك ، برايي موسم الر...           ld_ll1
# 70  @D7oommm131 حسيته مو مره مو زي موسم الرياض الص...         elaf9516
# 71  @ChrisWolf8_ ماش باقي مشخصنتها مع موسم الرياض ...          yuaeren
# 72  توقعت موسم الرياض هو اسوأ نسخه ممكن نشوفها من ...      xarcenciel_
# 73  #عقد_الرعايه_للشباب هذا القادح مو عنده شركات و...         abdule93
# 74  😭😭😭😭😭😭😭😭😭\n\nلابس تذكرت يوم كانوا يتكلمون عن م...         aeheeu6l
# 75  @ask_riyadh1 شوري لك تأجل جيتكم الى موسم الريا...    MonaAlotibi14
# 76  @ENG0H @SaudiNews50 حقيقي انه جميل جدااااااااا...           wz2040
# 77  هذا موسم الغرزة والطردة والتعنيف الشديد لصغار ...        Asmaalsal
# 78  بالله عليكم تقارنون الصغار بكبير الرياض بطل آس...          hamdf97
# 79  بالله عليكم تقارنون الصغار بكبير الرياض بطل آس...        Asmaalsal
# 80  يعني حطوا ثلاث أترام دراسة قللوا الإجازة الصيف...         iUrFahad
#
#                               location
# 0        جدة, المملكة العربية السعودية
# 1
# 2            Marrakesh Medina, Morocco
# 3                        تركيا.اسطنبول
# 4                               Riyadh
# 5              العلمانية فكر وليست كفر
# 6             المملكة العربية السعودية
# 7
# 8                          صنعاء الحرة
# 9
# 10                   ارض الله الواسعة
# 11
# 12                              Jeddah
# 13                        Cairo, Egypt
# 14            المملكة العربية السعودية
# 15       جدة, المملكة العربية السعودية
# 16
# 17      الحـياة فـي ظـل نـهاية العـالم
# 18                        Saudi Arabia
# 19
# 20                    kuwait♥  ins : ?
# 21                        دولة الكويت
# 22                              Makkah
# 23
# 24
# 25                         دولة الكويت
# 26                              الرياض
# 27                    بين أفاق النجوم
# 28                         دار ال سعود
# 29
# 30                    Riyadh | الرياض
# 31            المملكة العربية السعودية
# 32                              Riyadh
# 33                                   6
# 34  Al Khobar, Kingdom of Saudi Arabia
# 35                      Out of control
# 36
# 37      مكة المكرمة, المملكة العربية ا
# 38                                مشرف
# 39                            السعودية
# 40                      Al Khobar . .
# 41
# 42
# 43
# 44
# 45
# 46                              الرياض
# 47
# 48
# 49
# 50
# 51          tbz•loona•kep1er•elast•cix
# 52
# 53                       woosung lucas
# 54
# 55                    السعودية العظمى
# 56        مكتفيه في تويتر ...روح غريبه
# 57       جدة, المملكة العربية السعودية
# 58
# 59
# 60        أعيش بين الهـدوء و الموسيقى🎼
# 61
# 62
# 63      الرياض, المملكة العربية السعود
# 64                              Riyadh
# 65
# 66                   #السعودية_العظمى
# 67
# 68             Kingdom of Saudi Arabia
# 69            المملكة العربية السعودية
# 70
# 71
# 72
# 73
# 74                          Biomedical
# 75
# 76                              الرياض
# 77            المملكة العربية السعودية
# 78                          اليمن مارب
# 79            المملكة العربية السعودية
# 80                 ضيّ وسط ليلٍ عتيمْ-

# %%
#labeld dataset 
data = pd.read_csv('Riyadh_Season.csv')
# Keeping only the neccessary columns
data = data[['tweet','Category']]
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-d605f3694bf0> in <module>()
#       1 #labeld dataset
# ----> 2 data = pd.read_csv('Riyadh_Season.csv')
#       3 # Keeping only the neccessary columns
#       4 data = data[['tweet','Category']]
#       5 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Riyadh_Season.csv'

# %%
#Cleaning data

def clean_text(text):  
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى",
              "\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا",
               "","","","ي","",' ', ' ',' ',' ? ',' ؟ ', ' ! ']
    
    tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(tashkeel,"", text)  # remove Shadda,Fatha,Tanwin,Kasra..
    
    longation = re.compile(r'(.)\1+') 
    subst = r"\1\1"
    text = re.sub(longation, subst, text)   #remove longation  [إأآا]", "ا" or "ة", "ه",  ...
    
    text = re.sub(r"[^\w\s]", '', text)
    text = re.sub(r"[a-zA-Z]", '', text)
    text = re.sub(r"\d+", ' ', text)
    text = re.sub(r"\n+", ' ', text)
    text = re.sub(r"\t+", ' ', text)
    text = re.sub(r"\r+", ' ', text)
    text = re.sub(r"\s+", ' ', text)
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #text = data.strip()
    
    return text

# %%
data['cleaned_text'] = data.tweet.apply(clean_text)

data = data[data.cleaned_text != ""] #reomve any empty fields ?
data.head(10)

# %%
#num_samples in each category (Positive 1,negative -1,nautral 0)
#its a unbalanced dataset
data.groupby(['Category']).count()

# %%
#dealing with the unbalance 

min_sample = data.groupby(['Category']).count().cleaned_text.min()
b_data = pd.concat([data[data.Category == 1].head(min_sample), 
                        data[data.Category == -1].head(min_sample),
                     data[data.Category == 0].head(min_sample)])

b_data.groupby(['Category']).count()

# %%
X = data.cleaned_text.values #input

Y = data.Category.values.astype('float32') #target

# %%
#Tokenization Process

maxlen = 300
max_fatures = 800
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['cleaned_text'].values)
X = tokenizer.texts_to_sequences(data['cleaned_text'].values)
X = pad_sequences(X, padding='post', maxlen=maxlen)
X

# %%
seed=20

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,
                                                            random_state=seed)

print("Training:", len(X_train), len(Y_train))
print("Testing: ", len(X_test), len(Y_test))

# %%
from keras import layers
from keras.backend import clear_session

embedding_dim = 200
dropout = 0.5
opt = 'adam'
clear_session()

model = Sequential()
model.add(layers.Embedding(input_dim=max_fatures, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.Bidirectional(layers.LSTM(50, dropout=dropout, 
                                           recurrent_dropout=dropout, 
                                           return_sequences=True)))

model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(dropout))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(dropout))
model.add(layers.Dense(1, activation='relu'))

model.compile(optimizer=opt, 
              loss='binary_crossentropy', 
              metrics=['accuracy'])
model.summary()

# %%
#Training

history = model.fit(X_train, Y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, Y_test),
                    batch_size=64)

loss, accuracy = model.evaluate(X_train, Y_train, verbose=True)
print("Training Accuracy: {:.4f}".format(accuracy))

#TESTING ?
loss_val, accuracy_val = model.evaluate(X_test, Y_test, verbose=True)
print("Testing Accuracy:  {:.4f}".format(accuracy_val))

# %%
#Compre results:

df_blind = pd.DataFrame({'REAL': Y_blind, 
                         'PRED': pred_blind.reshape(pred_blind.shape[0],), 
                         'TEXT': blind_test.cleaned_text})
df_blind = df_blind.reset_index()[['REAL', 'PRED', 'TEXT']]
df_blind.PRED = df_blind.PRED.round()
error_records = df_blind[df_blind.REAL != df_blind.PRED]
print("Number of misclassified reviews: {} out of {}".format(error_records.shape[0], df_blind.shape[0]))
print("Blind Test Accuracy:  {:.4f}".format(accuracy_score(df_blind.REAL, df_blind.PRED)))

# %%
#Sample outputs:

df_blind.sample(n=3)
